# %%
a=[i for i in range(100000000)]
b=[i for i in range(100000000,200000000)]
c=[]
import time
start=time.time()
for i in range(len(a)):
    c.append(a[i]+b[i])
print(time.time()-start)
# Out:
# 10.720048427581787

# %%
import numpy as np
a=np.arange(100000000)
b=np.arange(100000000,200000000)
start=time.time()
c=a+b
print(time.time()-start)
# Out:
# 1.6014602184295654

# %%
# memory
a=[i for i in range(10000000)]
import sys
sys.getsizeof(a)
# Out:
# 89095160

# %%
a=np.arange(100000000,dtype=np.int64)
sys.getsizeof(a)
# Out:
# 800000112
